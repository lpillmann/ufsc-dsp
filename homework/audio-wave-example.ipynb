# %% [markdown]
# ## Plotting audio file

# %%
import matplotlib.pyplot as plt
import numpy as np
import wave
import sys


spf = wave.open('voice_example_mono.wav','r')

#Extract Raw Audio from Wav File
signal = spf.readframes(-1)
signal = np.fromstring(signal, 'Int16')


#If Stereo
if spf.getnchannels() == 2:
    print ('Just mono files')
    sys.exit(0)

plt.figure(1)
plt.title('Signal Wave...')
plt.plot(signal)
plt.show()

# %% [markdown]
# ## Playing plotted signal

# %%
import simpleaudio as sa

audio_data = spf.readframes(wave_read.getnframes())
num_channels = spf.getnchannels()
bytes_per_sample = spf.getsampwidth()
sample_rate = spf.getframerate()

play_obj = sa.play_buffer(signal, num_channels, bytes_per_sample, sample_rate)
play_obj.wait_done()
