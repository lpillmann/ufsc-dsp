# %%
from pylab import *
import scipy.signal as signal
from FIR_design import * # file provided as example at: http://mpastell.com/2010/01/18/fir-with-scipy/

# %%
n = 61
a = signal.firwin(n, cutoff=0.3, window="hamming")

# Frequency and phase response
mfreqz(a)
show()

# %%
# Impulse and step response
figure(2)
impz(a)
show()
